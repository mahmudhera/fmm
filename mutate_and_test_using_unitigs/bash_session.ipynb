# %%
g++ ./mutate_genome.cpp -O3
# Out:
# ./mutate_genome.cpp: In member function ‘std::tuple<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, long unsigned int, long unsigned int, long unsigned int, long unsigned int> mutation_model::mutate_string(int)’:
# ./mutate_genome.cpp:163:33: error: no match for ‘operator<<’ (operand types are ‘std::ofstream’ {aka ‘std::basic_ofstream<char>’} and ‘std::pair<std::__cxx11::basic_string<char>, std::__cxx11::basic_string<char> >’)
#   163 |             kmer_file_insertion << kmer << endl;
#       |             ~~~~~~~~~~~~~~~~~~~ ^~ ~~~~
#       |             |                      |
#       |             |                      std::pair<std::__cxx11::basic_string<char>, std::__cxx11::basic_string<char> >
#       |             std::ofstream {aka std::basic_ofstream<char>}
# In file included from /usr/include/c++/11/iostream:39,
#                  from ./mutate_genome.cpp:1:
# ...

# %%
./a.out
# Out:
# Usage: ./a.out seed orig_genome_filename p_s p_d d output_filename kmer_size
# : 1

# %%
./a.out 0 random.fasta 0.02 0.05 0.07 random_mutated.fasta 21

# %%
python process_unitigs.py -h
# Out:
# usage: process_unitigs.py [-h] orig_filename mut_filename k o
#
# positional arguments:
#   orig_filename  Filename of original string
#   mut_filename   Filename of mutated string
#   k              Length of k-mers
#   o              Output filename
#
# optional arguments:
#   -h, --help     show this help message and exit

# %%
conda activate fancy

# %%
time python process_unitigs.py ndl.fasta ndl_mutated.fasta 21 out_process_unitigs --cut_off 1.0
# Out:
# Done, now aggregating results and writing to output file
#
# real	4m46.019s
# user	94m55.131s
# sys	3m26.648s

# %%
git commit -a -m "update from the remote server"
git push
# Out:
# [main 5d8254d] update from the remote server
#  8 files changed, 34873 insertions(+), 38654 deletions(-)
#  rewrite mutate_and_test_using_unitigs/kmers_single_deletion (91%)
#  rewrite mutate_and_test_using_unitigs/kmers_single_insertion (87%)
#  rewrite mutate_and_test_using_unitigs/kmers_single_substitution (97%)
# Enumerating objects: 21, done.
# Counting objects: 100% (21/21), done.
# Delta compression using up to 255 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (11/11), 169.01 KiB | 2.41 MiB/s, done.
# Total 11 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To github.com:mahmudhera/fmm.git
#    738c866..5d8254d  main -> main

# %%
time python process_unitigs.py random.fasta random_mutated.fasta 21 out_process_unitigs --cut_off 1.0 --run_cuttlefish
# Out:
# cuttlefish build -s random.fasta -k 21 -t 128 -o random.fasta_unitigs -w . --ref
# cuttlefish build -s random_mutated.fasta -k 21 -t 128 -o random_mutated.fasta_unitigs -w . --ref
#
# Constructing the compacted reference de Bruijn graph for k = 21.
#
# Enumerating the edges of the de Bruijn graph.
# **
# Stage 1: 100%
# ...
#
# Constructing the compacted reference de Bruijn graph for k = 21.
#
# Enumerating the edges of the de Bruijn graph.
# **
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# 22-mer enumeration statistics:
# 	Number of sequences:	1.
# 	Total sequence length:	101841.
# 	Total number of 22-mers:	101820.
# 	Number of unique 22-mers:	101820.
# 	Number of solid 22-mers:	101820.
# Enumerated the edge set of the graph. Time taken = 6.42724 seconds.
#
# Enumerating the vertices of the de Bruijn graph.
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# Enumerated the vertex set of the graph. Time taken = 4.54951 seconds.
# Number of edges:    101820.
# Number of vertices: 101821.
#
# ...

# %%
git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 364 bytes | 364.00 KiB/s, done.
# From github.com:mahmudhera/fmm
#    2d56037..a3fe6c3  main       -> origin/main
# Updating 2d56037..a3fe6c3
# Fast-forward
#  mutate_and_test_using_unitigs/estimate_SD.py | 6 +++---
#  1 file changed, 3 insertions(+), 3 deletions(-)

# %%
./a.out 0 random.fasta 0.00 0.05 0.07 random_mutated.fasta 21

# %%
rm random.fasta_unitigs*
cuttlefish build -s random.fasta -k 21 -t 128 -o random.fasta_unitigs -w . --ref
# Out:
# Constructing the compacted reference de Bruijn graph for k = 21.
#
# Enumerating the edges of the de Bruijn graph.
# **
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# 22-mer enumeration statistics:
# 	Number of sequences:	1.
# 	Total sequence length:	100000.
# 	Total number of 22-mers:	99979.
# 	Number of unique 22-mers:	50182.
# 	Number of solid 22-mers:	50182.
# Enumerated the edge set of the graph. Time taken = 6.42468 seconds.
#
# Enumerating the vertices of the de Bruijn graph.
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# Enumerated the vertex set of the graph. Time taken = 4.49699 seconds.
# Number of edges:    50182.
# Number of vertices: 50173.
#
# Constructing the minimal perfect hash function (MPHF) over the vertex set.
# Total number of k-mers in the set (KMC database): 50173.
# Building the MPHF from the k-mer database ./random.fasta_unitigs.cf_V.
# Using gamma = 10.
# [Building BooPHF]  46.5 %   elapsed:   0 min 0  sec   remaining:   0 min 0  sec
# ...

# %%
rm random_mutated.fasta_unitigs*
cuttlefish build -s random_mutated.fasta -k 21 -t 128 -o random_mutated.fasta_unitigs -w . --ref
# Out:
# Constructing the compacted reference de Bruijn graph for k = 21.
#
# Enumerating the edges of the de Bruijn graph.
# **
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# 22-mer enumeration statistics:
# 	Number of sequences:	1.
# 	Total sequence length:	101843.
# 	Total number of 22-mers:	101822.
# 	Number of unique 22-mers:	101304.
# 	Number of solid 22-mers:	101304.
# Enumerated the edge set of the graph. Time taken = 6.37394 seconds.
#
# Enumerating the vertices of the de Bruijn graph.
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# Enumerated the vertex set of the graph. Time taken = 4.41622 seconds.
# Number of edges:    101304.
# Number of vertices: 101163.
#
# Constructing the minimal perfect hash function (MPHF) over the vertex set.
# Total number of k-mers in the set (KMC database): 101163.
# Building the MPHF from the k-mer database ./random_mutated.fasta_unitigs.cf_V.
# Using gamma = 10.
# [Building BooPHF]  47.1 %   elapsed:   0 min 0  sec   remaining:   0 min 0  sec
# ...

# %%
rm ndl.fasta_unitigs*
cuttlefish build -s ndl.fasta -k 21 -t 128 -o ndl.fasta_unitigs -w . --ref
rm ndl_mutated.fasta_unitigs*
cuttlefish build -s ndl_mutated.fasta -k 21 -t 128 -o ndl_mutated.fasta_unitigs -w . --ref
# Out:
# Constructing the compacted reference de Bruijn graph for k = 21.
#
# Enumerating the edges of the de Bruijn graph.
# **
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# 22-mer enumeration statistics:
# 	Number of sequences:	1.
# 	Total sequence length:	111937.
# 	Total number of 22-mers:	111916.
# 	Number of unique 22-mers:	111692.
# 	Number of solid 22-mers:	111692.
# Enumerated the edge set of the graph. Time taken = 6.37223 seconds.
#
# Enumerating the vertices of the de Bruijn graph.
# Stage 1: 100%
# ...
# Stage 2: 100%
#
#
# Enumerated the vertex set of the graph. Time taken = 4.41746 seconds.
# Number of edges:    111692.
# Number of vertices: 111522.
#
# Constructing the minimal perfect hash function (MPHF) over the vertex set.
# Total number of k-mers in the set (KMC database): 111522.
# Building the MPHF from the k-mer database ./ndl.fasta_unitigs.cf_V.
# Using gamma = 10.
# [Building BooPHF]  47.1 %   elapsed:   0 min 0  sec   remaining:   0 min 0  sec
# ...

# %%
cd /scratch/mbr5797/fancy_mut_model_new/fmm/using_edlib

# %%
python data/random.fasta 21 --length 100000 --chunk_size 5000 --num_chunks 10 --seed 0
# Out:
# python: can't open file 'data/random.fasta': [Errno 2] No such file or directory
# : 2

# %%
git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 353 bytes | 353.00 KiB/s, done.
# From github.com:mahmudhera/fmm
#    66f5ee5..29397d6  main       -> origin/main
# Updating 66f5ee5..29397d6
# Fast-forward
#  using_edlib/main.py | 6 +++++-
#  1 file changed, 5 insertions(+), 1 deletion(-)
